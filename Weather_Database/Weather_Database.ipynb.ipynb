# %%
# Import initial libraries

import numpy as np

import pandas as pd

from citipy import citipy

from config import weather_api_key

# Import the requests library

import requests

# Import the time library

import time

# Import the datetime module from the datetime library

from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)

lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %%
# Create an empty list for holding the cities

cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 630

# %%
# Assemble the OpenWeatherMap's API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c34ddd8ec0dfea1c6836a01c627e5e25

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval         ")

print("---------------------------------------")

# Create counters.

record_count = 1

set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into the city_data list.
        
        city_data.append({"City": city.title(),
                          
                         "Country": city_country,
                          
                         "Lat": city_lat,
                          
                         "Lng": city_lng,
                          
                         "Max Temp": city_max_temp,
                          
                         "Humidity": city_humidity,
                          
                         "Cloudiness": city_clouds,
                          
                         "Wind Speed": city_wind,
                          
                         "Weather Description": city_description,})
        
    # If an error is experience, skip the city.
    
    except:
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.

print("-----------------------------------------")
print("Data Retrieval Complete            ")
print("-----------------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------------
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | piterka
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | nsoko
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | aklavik
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | yulara
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | mokolo
# Processing Record 22 of Set 1 | saint-pierre
# Processing Record 23 of Set 1 | nenjiang
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 1 | tanout
# Processing Record 29 of Set 1 | te anau
# Processing Record 30 of Set 1 | marawi
# Processing Record 31 of Set 1 | jieshi
# Processing Record 32 of Set 1 | tura
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | sambava
# Processing Record 35 of Set 1 | pogranichnyy
# Processing Record 36 of Set 1 | nagato
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | luorong
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | khani
# Processing Record 43 of Set 1 | muskogee
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | sibolga
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | guerrero negro
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | oksfjord
# Processing Record 50 of Set 1 | lahore
# Processing Record 1 of Set 2 | calvinia
# Processing Record 2 of Set 2 | candelaria
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | kahului
# Processing Record 7 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | adrar
# Processing Record 9 of Set 2 | nyurba
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | fortuna
# Processing Record 12 of Set 2 | laguna
# Processing Record 13 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | pochutla
# Processing Record 19 of Set 2 | asau
# Processing Record 20 of Set 2 | lokosovo
# Processing Record 21 of Set 2 | tiznit
# Processing Record 22 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 2 | ambunti
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | longonjo
# Processing Record 26 of Set 2 | buala
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | rock sound
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | saint-louis
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | saint anthony
# Processing Record 36 of Set 2 | vao
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | tibati
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | cairns
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | grindavik
# Processing Record 43 of Set 2 | pevek
# Processing Record 44 of Set 2 | suntar
# Processing Record 45 of Set 2 | sangar
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 2 | pangnirtung
# Processing Record 49 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 2 | hualmay
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | kalmunai
# Processing Record 3 of Set 3 | kimbe
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | tual
# Processing Record 6 of Set 3 | road town
# Processing Record 7 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 8 of Set 3 | cayenne
# Processing Record 9 of Set 3 | lata
# Processing Record 10 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 11 of Set 3 | wajima
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | meulaboh
# Processing Record 14 of Set 3 | kungurtug
# Processing Record 15 of Set 3 | dingle
# Processing Record 16 of Set 3 | changuinola
# Processing Record 17 of Set 3 | srednekolymsk
# Processing Record 18 of Set 3 | herat
# Processing Record 19 of Set 3 | la rioja
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | haines junction
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | znamenskoye
# Processing Record 25 of Set 3 | atar
# Processing Record 26 of Set 3 | constantine
# Processing Record 27 of Set 3 | san patricio
# Processing Record 28 of Set 3 | port hedland
# Processing Record 29 of Set 3 | saint marys
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | comodoro rivadavia
# Processing Record 33 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | namibe
# Processing Record 36 of Set 3 | port macquarie
# Processing Record 37 of Set 3 | new norfolk
# Processing Record 38 of Set 3 | marystown
# Processing Record 39 of Set 3 | manyana
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | mitsamiouli
# Processing Record 42 of Set 3 | ekibastuz
# Processing Record 43 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 44 of Set 3 | dakar
# Processing Record 45 of Set 3 | mount isa
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | viedma
# Processing Record 48 of Set 3 | naze
# Processing Record 49 of Set 3 | broome
# Processing Record 50 of Set 3 | shingu
# Processing Record 1 of Set 4 | neiafu
# Processing Record 2 of Set 4 | sitka
# Processing Record 3 of Set 4 | broken hill
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | baoning
# Processing Record 7 of Set 4 | blytheville
# Processing Record 8 of Set 4 | praxedis guerrero
# Processing Record 9 of Set 4 | erenhot
# Processing Record 10 of Set 4 | sabya
# Processing Record 11 of Set 4 | saryg-sep
# Processing Record 12 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | iracoubo
# Processing Record 15 of Set 4 | port-gentil
# Processing Record 16 of Set 4 | cidreira
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | zhigansk
# Processing Record 19 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 4 | casablanca
# Processing Record 21 of Set 4 | lazaro cardenas
# Processing Record 22 of Set 4 | chumikan
# Processing Record 23 of Set 4 | port augusta
# Processing Record 24 of Set 4 | ixtapa
# Processing Record 25 of Set 4 | marzuq
# Processing Record 26 of Set 4 | kilinochchi
# Processing Record 27 of Set 4 | dabhol
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | vestmannaeyjar
# Processing Record 30 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 4 | colonia
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | chimore
# Processing Record 34 of Set 4 | inhambane
# Processing Record 35 of Set 4 | sao joao da barra
# Processing Record 36 of Set 4 | zhangjiakou
# Processing Record 37 of Set 4 | portland
# Processing Record 38 of Set 4 | egvekinot
# Processing Record 39 of Set 4 | dali
# Processing Record 40 of Set 4 | sola
# Processing Record 41 of Set 4 | mandalgovi
# Processing Record 42 of Set 4 | iisalmi
# Processing Record 43 of Set 4 | xuanhua
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | west lafayette
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | sehithwa
# Processing Record 48 of Set 4 | changji
# Processing Record 49 of Set 4 | shimoda
# Processing Record 50 of Set 4 | seydi
# Processing Record 1 of Set 5 | nouadhibou
# Processing Record 2 of Set 5 | srikakulam
# Processing Record 3 of Set 5 | camopi
# Processing Record 4 of Set 5 | sabang
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | lasa
# Processing Record 8 of Set 5 | wanxian
# Processing Record 9 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 5 | nichinan
# Processing Record 11 of Set 5 | dunedin
# Processing Record 12 of Set 5 | hofn
# Processing Record 13 of Set 5 | wucheng
# Processing Record 14 of Set 5 | sao miguel do araguaia
# Processing Record 15 of Set 5 | cleethorpes
# Processing Record 16 of Set 5 | fraga
# Processing Record 17 of Set 5 | qunduz
# Processing Record 18 of Set 5 | harbour breton
# Processing Record 19 of Set 5 | sioux lookout
# Processing Record 20 of Set 5 | kemijarvi
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | santa maria
# Processing Record 23 of Set 5 | kumano
# Processing Record 24 of Set 5 | seoul
# Processing Record 25 of Set 5 | mahajanga
# Processing Record 26 of Set 5 | buin
# Processing Record 27 of Set 5 | linqiong
# Processing Record 28 of Set 5 | ola
# Processing Record 29 of Set 5 | coquimbo
# Processing Record 30 of Set 5 | nouakchott
# Processing Record 31 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 32 of Set 5 | ambilobe
# Processing Record 33 of Set 5 | prieska
# Processing Record 34 of Set 5 | sobolevo
# Processing Record 35 of Set 5 | noumea
# Processing Record 36 of Set 5 | urusha
# Processing Record 37 of Set 5 | bathsheba
# Processing Record 38 of Set 5 | cumberland
# Processing Record 39 of Set 5 | aberdeen
# Processing Record 40 of Set 5 | shushtar
# Processing Record 41 of Set 5 | filadelfia
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | nazret
# Processing Record 44 of Set 5 | vaitape
# Processing Record 45 of Set 5 | irbeyskoye
# Processing Record 46 of Set 5 | mizdah
# Processing Record 47 of Set 5 | maneadero
# Processing Record 48 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 5 | luderitz
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | tabas
# Processing Record 2 of Set 6 | zemio
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | ossora
# Processing Record 5 of Set 6 | springbok
# Processing Record 6 of Set 6 | tilichiki
# Processing Record 7 of Set 6 | baracoa
# Processing Record 8 of Set 6 | frankenberg
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | husavik
# Processing Record 11 of Set 6 | elko
# Processing Record 12 of Set 6 | abu kamal
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | ponta do sol
# Processing Record 15 of Set 6 | bengkulu
# Processing Record 16 of Set 6 | upernavik
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | bilibino
# Processing Record 19 of Set 6 | ponta delgada
# Processing Record 20 of Set 6 | nara
# Processing Record 21 of Set 6 | grand gaube
# Processing Record 22 of Set 6 | bandarbeyla
# Processing Record 23 of Set 6 | skjervoy
# Processing Record 24 of Set 6 | ilulissat
# Processing Record 25 of Set 6 | harper
# Processing Record 26 of Set 6 | lichfield
# Processing Record 27 of Set 6 | sens
# Processing Record 28 of Set 6 | aden
# Processing Record 29 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 6 | chiknayakanhalli
# Processing Record 31 of Set 6 | ust-tsilma
# Processing Record 32 of Set 6 | kavieng
# Processing Record 33 of Set 6 | paungde
# Processing Record 34 of Set 6 | roza
# Processing Record 35 of Set 6 | danielskuil
# Processing Record 36 of Set 6 | ariquemes
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | nanyamba
# Processing Record 39 of Set 6 | angoram
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | port lincoln
# Processing Record 43 of Set 6 | hastings
# Processing Record 44 of Set 6 | hakvik
# City not found. Skipping...
# Processing Record 45 of Set 6 | balkhash
# Processing Record 46 of Set 6 | iquique
# Processing Record 47 of Set 6 | lillooet
# Processing Record 48 of Set 6 | fangshan
# Processing Record 49 of Set 6 | half moon bay
# Processing Record 50 of Set 6 | verkhoyansk
# Processing Record 1 of Set 7 | dwarka
# Processing Record 2 of Set 7 | esperance
# Processing Record 3 of Set 7 | ambon
# Processing Record 4 of Set 7 | oistins
# Processing Record 5 of Set 7 | isangel
# Processing Record 6 of Set 7 | wahiawa
# Processing Record 7 of Set 7 | abu samrah
# Processing Record 8 of Set 7 | kamina
# Processing Record 9 of Set 7 | balaka
# Processing Record 10 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 7 | lishui
# Processing Record 12 of Set 7 | swellendam
# Processing Record 13 of Set 7 | firovo
# Processing Record 14 of Set 7 | padang
# Processing Record 15 of Set 7 | bay roberts
# Processing Record 16 of Set 7 | taksimo
# Processing Record 17 of Set 7 | marsabit
# Processing Record 18 of Set 7 | dutlwe
# Processing Record 19 of Set 7 | kishi
# Processing Record 20 of Set 7 | caravelas
# Processing Record 21 of Set 7 | yeppoon
# Processing Record 22 of Set 7 | ahipara
# Processing Record 23 of Set 7 | cedar lake
# Processing Record 24 of Set 7 | mahebourg
# Processing Record 25 of Set 7 | pisco
# Processing Record 26 of Set 7 | mantua
# Processing Record 27 of Set 7 | bambous virieux
# Processing Record 28 of Set 7 | ciudad ojeda
# Processing Record 29 of Set 7 | valley city
# Processing Record 30 of Set 7 | sao filipe
# Processing Record 31 of Set 7 | hithadhoo
# Processing Record 32 of Set 7 | henties bay
# Processing Record 33 of Set 7 | humboldt
# Processing Record 34 of Set 7 | kichera
# Processing Record 35 of Set 7 | anadyr
# Processing Record 36 of Set 7 | kirovsk
# Processing Record 37 of Set 7 | necochea
# Processing Record 38 of Set 7 | galbshtadt
# Processing Record 39 of Set 7 | lodja
# Processing Record 40 of Set 7 | wenling
# Processing Record 41 of Set 7 | wexford
# Processing Record 42 of Set 7 | poya
# Processing Record 43 of Set 7 | wagar
# Processing Record 44 of Set 7 | kuznechnoye
# Processing Record 45 of Set 7 | kieta
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | raxaul
# Processing Record 48 of Set 7 | kembe
# Processing Record 49 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 7 | salvador
# Processing Record 1 of Set 8 | mayo
# Processing Record 2 of Set 8 | catamarca
# Processing Record 3 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 8 | woodward
# Processing Record 5 of Set 8 | itoman
# Processing Record 6 of Set 8 | kinablangan
# Processing Record 7 of Set 8 | coihaique
# Processing Record 8 of Set 8 | harwich
# Processing Record 9 of Set 8 | arraial do cabo
# Processing Record 10 of Set 8 | port arthur
# Processing Record 11 of Set 8 | dzerzhinskoye
# Processing Record 12 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 13 of Set 8 | nanortalik
# Processing Record 14 of Set 8 | poum
# Processing Record 15 of Set 8 | brae
# Processing Record 16 of Set 8 | sawai madhopur
# Processing Record 17 of Set 8 | pozo colorado
# Processing Record 18 of Set 8 | tamiahua
# Processing Record 19 of Set 8 | port blair
# Processing Record 20 of Set 8 | pemex
# Processing Record 21 of Set 8 | olinda
# Processing Record 22 of Set 8 | severo-kurilsk
# Processing Record 23 of Set 8 | ishigaki
# Processing Record 24 of Set 8 | bodden town
# Processing Record 25 of Set 8 | ismailia
# Processing Record 26 of Set 8 | college
# Processing Record 27 of Set 8 | tolaga bay
# Processing Record 28 of Set 8 | xuddur
# Processing Record 29 of Set 8 | kyren
# Processing Record 30 of Set 8 | garowe
# Processing Record 31 of Set 8 | uray
# Processing Record 32 of Set 8 | randvere
# City not found. Skipping...
# Processing Record 33 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 8 | high rock
# Processing Record 35 of Set 8 | mayumba
# Processing Record 36 of Set 8 | richards bay
# Processing Record 37 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 8 | charters towers
# Processing Record 39 of Set 8 | rawson
# Processing Record 40 of Set 8 | praia
# Processing Record 41 of Set 8 | thompson
# Processing Record 42 of Set 8 | phuket
# Processing Record 43 of Set 8 | nabul
# City not found. Skipping...
# Processing Record 44 of Set 8 | saint george
# Processing Record 45 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 8 | quelimane
# Processing Record 47 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 48 of Set 8 | katherine
# Processing Record 49 of Set 8 | tiksi
# Processing Record 50 of Set 8 | kavaratti
# Processing Record 1 of Set 9 | akdepe
# Processing Record 2 of Set 9 | faanui
# Processing Record 3 of Set 9 | otane
# Processing Record 4 of Set 9 | marsh harbour
# Processing Record 5 of Set 9 | yendi
# Processing Record 6 of Set 9 | holguin
# Processing Record 7 of Set 9 | oytal
# Processing Record 8 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 9 | coro
# Processing Record 10 of Set 9 | kostek
# Processing Record 11 of Set 9 | muros
# Processing Record 12 of Set 9 | noshiro
# Processing Record 13 of Set 9 | rantauprapat
# Processing Record 14 of Set 9 | monte carmelo
# Processing Record 15 of Set 9 | kapit
# Processing Record 16 of Set 9 | bafq
# Processing Record 17 of Set 9 | beyneu
# Processing Record 18 of Set 9 | dudinka
# Processing Record 19 of Set 9 | tosagua
# Processing Record 20 of Set 9 | saint-francois
# Processing Record 21 of Set 9 | kutum
# Processing Record 22 of Set 9 | itarema
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | san javier
# Processing Record 25 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 9 | gurgentepe
# Processing Record 27 of Set 9 | mecca
# Processing Record 28 of Set 9 | hokitika
# Processing Record 29 of Set 9 | burgersdorp
# Processing Record 30 of Set 9 | jefferson city
# Processing Record 31 of Set 9 | ambulu
# Processing Record 32 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | sorong
# Processing Record 34 of Set 9 | avera
# Processing Record 35 of Set 9 | porto belo
# Processing Record 36 of Set 9 | codrington
# Processing Record 37 of Set 9 | nantucket
# Processing Record 38 of Set 9 | luebo
# Processing Record 39 of Set 9 | san cristobal
# Processing Record 40 of Set 9 | catemaco
# Processing Record 41 of Set 9 | bilma
# Processing Record 42 of Set 9 | florence
# Processing Record 43 of Set 9 | palkino
# Processing Record 44 of Set 9 | kalakamati
# Processing Record 45 of Set 9 | talara
# Processing Record 46 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 9 | port-cartier
# Processing Record 48 of Set 9 | bad hersfeld
# Processing Record 49 of Set 9 | emet
# Processing Record 50 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 10 | airai
# Processing Record 2 of Set 10 | juneau
# Processing Record 3 of Set 10 | krasnoselkup
# Processing Record 4 of Set 10 | shaunavon
# Processing Record 5 of Set 10 | saint-augustin
# Processing Record 6 of Set 10 | pemangkat
# Processing Record 7 of Set 10 | santa fe
# Processing Record 8 of Set 10 | nardaran
# Processing Record 9 of Set 10 | kiunga
# Processing Record 10 of Set 10 | nizhniy ingash
# Processing Record 11 of Set 10 | glubokoe
# City not found. Skipping...
# Processing Record 12 of Set 10 | corsicana
# Processing Record 13 of Set 10 | ashington
# Processing Record 14 of Set 10 | fort nelson
# Processing Record 15 of Set 10 | klyuchi
# Processing Record 16 of Set 10 | kidal
# Processing Record 17 of Set 10 | tabou
# Processing Record 18 of Set 10 | kashi
# Processing Record 19 of Set 10 | honningsvag
# Processing Record 20 of Set 10 | los llanos de aridane
# Processing Record 21 of Set 10 | khandyga
# Processing Record 22 of Set 10 | ayoquezco
# City not found. Skipping...
# Processing Record 23 of Set 10 | miranda
# Processing Record 24 of Set 10 | paulo ramos
# Processing Record 25 of Set 10 | santa cruz
# Processing Record 26 of Set 10 | zaplyusye
# City not found. Skipping...
# Processing Record 27 of Set 10 | izhma
# Processing Record 28 of Set 10 | turmalina
# Processing Record 29 of Set 10 | umm lajj
# Processing Record 30 of Set 10 | tottori
# Processing Record 31 of Set 10 | puerto del rosario
# Processing Record 32 of Set 10 | lahij
# Processing Record 33 of Set 10 | havre-saint-pierre
# Processing Record 34 of Set 10 | alofi
# Processing Record 35 of Set 10 | mehamn
# Processing Record 36 of Set 10 | soyo
# Processing Record 37 of Set 10 | sisimiut
# Processing Record 38 of Set 10 | quatre cocos
# Processing Record 39 of Set 10 | namatanai
# Processing Record 40 of Set 10 | taoudenni
# Processing Record 41 of Set 10 | yashan
# Processing Record 42 of Set 10 | vila franca do campo
# Processing Record 43 of Set 10 | conde
# Processing Record 44 of Set 10 | port moresby
# Processing Record 45 of Set 10 | belmonte
# Processing Record 46 of Set 10 | alice springs
# Processing Record 47 of Set 10 | pangody
# Processing Record 48 of Set 10 | hoshangabad
# Processing Record 49 of Set 10 | acari
# Processing Record 50 of Set 10 | buraydah
# Processing Record 1 of Set 11 | raudeberg
# Processing Record 2 of Set 11 | lake havasu city
# Processing Record 3 of Set 11 | fairbanks
# Processing Record 4 of Set 11 | douglas
# Processing Record 5 of Set 11 | kizhinga
# Processing Record 6 of Set 11 | cascais
# Processing Record 7 of Set 11 | shache
# Processing Record 8 of Set 11 | hobyo
# Processing Record 9 of Set 11 | kibala
# Processing Record 10 of Set 11 | kangaatsiaq
# Processing Record 11 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 11 | banff
# Processing Record 13 of Set 11 | warri
# Processing Record 14 of Set 11 | luganville
# Processing Record 15 of Set 11 | narsaq
# Processing Record 16 of Set 11 | dingli
# Processing Record 17 of Set 11 | palizada
# Processing Record 18 of Set 11 | jiangyou
# Processing Record 19 of Set 11 | tadine
# Processing Record 20 of Set 11 | chapais
# Processing Record 21 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 11 | lukovetskiy
# Processing Record 23 of Set 11 | ferme-neuve
# Processing Record 24 of Set 11 | petropavlovka
# Processing Record 25 of Set 11 | miandrivazo
# Processing Record 26 of Set 11 | piopio
# Processing Record 27 of Set 11 | saint thomas mount
# Processing Record 28 of Set 11 | hovd
# Processing Record 29 of Set 11 | strezhevoy
# Processing Record 30 of Set 11 | novikovo
# Processing Record 31 of Set 11 | dobrinka
# Processing Record 32 of Set 11 | constitucion
# Processing Record 33 of Set 11 | flagstaff
# Processing Record 34 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 35 of Set 11 | kailua
# Processing Record 36 of Set 11 | leningradskiy
# Processing Record 37 of Set 11 | cherskiy
# Processing Record 38 of Set 11 | north battleford
# Processing Record 39 of Set 11 | kamsack
# Processing Record 40 of Set 11 | mogadishu
# Processing Record 41 of Set 11 | adre
# Processing Record 42 of Set 11 | mareeba
# Processing Record 43 of Set 11 | jalu
# Processing Record 44 of Set 11 | agadez
# Processing Record 45 of Set 11 | enid
# Processing Record 46 of Set 11 | zhicheng
# Processing Record 47 of Set 11 | rocha
# Processing Record 48 of Set 11 | longido
# Processing Record 49 of Set 11 | vilhena
# Processing Record 50 of Set 11 | trinidad
# Processing Record 1 of Set 12 | santa vitoria do palmar
# Processing Record 2 of Set 12 | kytlym
# City not found. Skipping...
# Processing Record 3 of Set 12 | muzaffargarh
# Processing Record 4 of Set 12 | middle island
# Processing Record 5 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 6 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 7 of Set 12 | hay river
# Processing Record 8 of Set 12 | wenzhou
# Processing Record 9 of Set 12 | schluchtern
# Processing Record 10 of Set 12 | augusto correa
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | ust-barguzin
# Processing Record 13 of Set 12 | jacareacanga
# Processing Record 14 of Set 12 | tromso
# Processing Record 15 of Set 12 | jarjis
# City not found. Skipping...
# Processing Record 16 of Set 12 | torbay
# Processing Record 17 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 12 | champasak
# Processing Record 19 of Set 12 | nirasaki
# Processing Record 20 of Set 12 | majene
# Processing Record 21 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 12 | roseburg
# Processing Record 23 of Set 12 | san rafael
# Processing Record 24 of Set 12 | ada
# Processing Record 25 of Set 12 | zhanaozen
# Processing Record 26 of Set 12 | bulaevo
# Processing Record 27 of Set 12 | esmeraldas
# Processing Record 28 of Set 12 | farafangana
# Processing Record 29 of Set 12 | boundiali
# Processing Record 30 of Set 12 | lermontovka
# Processing Record 31 of Set 12 | ust-omchug
# Processing Record 32 of Set 12 | ikongo
# Processing Record 33 of Set 12 | warwick
# Processing Record 34 of Set 12 | iraan
# Processing Record 35 of Set 12 | sault sainte marie
# Processing Record 36 of Set 12 | guhagar
# Processing Record 37 of Set 12 | tautira
# Processing Record 38 of Set 12 | kizukuri
# Processing Record 39 of Set 12 | balung
# Processing Record 40 of Set 12 | puerto palomas
# Processing Record 41 of Set 12 | belaya gora
# Processing Record 42 of Set 12 | kupang
# Processing Record 43 of Set 12 | nome
# Processing Record 44 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 12 | tabuk
# Processing Record 46 of Set 12 | moura
# Processing Record 47 of Set 12 | bisho
# Processing Record 48 of Set 12 | gilgit
# Processing Record 49 of Set 12 | okhotsk
# Processing Record 50 of Set 12 | gizo
# Processing Record 1 of Set 13 | bad wildbad
# Processing Record 2 of Set 13 | tooele
# Processing Record 3 of Set 13 | sarkand
# Processing Record 4 of Set 13 | rio gallegos
# Processing Record 5 of Set 13 | ternate
# Processing Record 6 of Set 13 | acajutla
# Processing Record 7 of Set 13 | boli
# Processing Record 8 of Set 13 | san quintin
# Processing Record 9 of Set 13 | havoysund
# Processing Record 10 of Set 13 | batemans bay
# Processing Record 11 of Set 13 | derzhavinsk
# Processing Record 12 of Set 13 | goure
# Processing Record 13 of Set 13 | campos
# Processing Record 14 of Set 13 | pitsunda
# Processing Record 15 of Set 13 | malayal
# Processing Record 16 of Set 13 | ukiah
# Processing Record 17 of Set 13 | alakurtti
# Processing Record 18 of Set 13 | noyabrsk
# Processing Record 19 of Set 13 | khatima
# Processing Record 20 of Set 13 | sohbatpur
# Processing Record 21 of Set 13 | karwar
# Processing Record 22 of Set 13 | arlit
# Processing Record 23 of Set 13 | gat
# Processing Record 24 of Set 13 | esfahan
# Processing Record 25 of Set 13 | karratha
# Processing Record 26 of Set 13 | north bend
# Processing Record 27 of Set 13 | basco
# Processing Record 28 of Set 13 | turukhansk
# Processing Record 29 of Set 13 | snasa
# Processing Record 30 of Set 13 | aykhal
# -----------------------------------------
# Data Retrieval Complete
# -----------------------------------------

# %%
# Print the length of the city_data list to verify how many cities you have

len(city_data)
# Out:
# 579

# %%
# Use the city_data list to create a new pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Lebu      CL -37.6167  -73.6500     62.89        77          24
# 1     Khatanga      RU  71.9667  102.5000    -30.03        99         100
# 2  East London      ZA -33.0153   27.9116     64.33        81          84
# 3   Nikolskoye      RU  59.7035   30.7861     -0.20        88          75
# 4      Piterka      RU  50.6803   47.4454     -3.89        87           7
# 5      Ushuaia      AR -54.8000  -68.3000     64.06        36          20
# 6        Nsoko      SZ -27.0333   31.9500     58.26        90           4
# 7        Vaini      TO -21.2000 -175.2000     86.16        79          40
# 8      Aklavik      CA  68.2191 -135.0107     -5.80        77          40
# 9      Rikitea      PF -23.1203 -134.9692     78.30        74           1
#
#    Wind Speed Weather Description
# 0        8.10          few clouds
# 1        1.63     overcast clouds
# 2        7.07       broken clouds
# 3        4.83       broken clouds
# 4       11.27           clear sky
# 5       11.50          few clouds
# 6        4.50           clear sky
# 7       13.80    scattered clouds
# 8        0.00    scattered clouds
# 9       14.12           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function

city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:

# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Weather description"

new_column_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order

city_data_df= city_data_df[new_column_order]

# Display sample data

city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lebu      CL -37.6167  -73.6500     62.89        77          24
# 1       Khatanga      RU  71.9667  102.5000    -30.03        99         100
# 2    East London      ZA -33.0153   27.9116     64.33        81          84
# 3     Nikolskoye      RU  59.7035   30.7861     -0.20        88          75
# 4        Piterka      RU  50.6803   47.4454     -3.89        87           7
# ..           ...     ...      ...       ...       ...       ...         ...
# 574   North Bend      US  43.4065 -124.2243     54.16        91         100
# 575        Basco      PH  20.4487  121.9702     74.46        77          72
# 576   Turukhansk      RU  65.8167   87.9833    -51.99        96          26
# 577        Snasa      NO  64.2457   12.3778     31.41        94         100
# 578       Aykhal      RU  66.0000  111.5000    -44.81       100         100
#
#      Wind Speed Weather Description
# 0          8.10          few clouds
# 1          1.63     overcast clouds
# 2          7.07       broken clouds
# 3          4.83       broken clouds
# 4         11.27           clear sky
# ..          ...                 ...
# 574        9.22     overcast clouds
# 575       22.53       broken clouds
# 576        3.38    scattered clouds
# 577        7.74          light snow
# 578        4.43     overcast clouds
#
# [579 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function

city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %%
# Set the output file name

output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file

city_data_df.to_csv(output_data_file, index_label="City_ID")
